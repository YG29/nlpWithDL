# %%
import pandas as pd

# %%
df = pd.read_csv("../final_annotations/combined_annotations.csv")

# %%
sample_df = df.sample(n=20, random_state=192).copy()

# %%
columns_to_keep = ["domain", "scenario", "system_instruction", "distractors"]
sample_df = sample_df[columns_to_keep]

# %%
print(sample_df.head())
# Out:
#      domain                                           scenario  \
# 88    legal  4. Facilitating international trade agreements...
# 11  banking           Ordering a new batch of personal checks.
# 52   health  exploring options for addiction treatment and ...
# 22  banking  Setting up automatic bill payments from a chec...
# 95    legal  9. Handling a discrimination claim filed with ...
#
#                                    system_instruction  \
# 88  When engaging in discussions related to facili...
# 11  When interacting with a user who wants to orde...
# 52  In the context of addiction treatment and coun...
# 22  When interacting with a user who wants to set ...
# 95  When handling a discrimination claim filed wit...
#
#                                           distractors
# 88  [{"bot turn": "Of course, I'd be happy to help...
# 11  [{"bot turn": "Thank you for providing your ac...
# 52  [{"bot turn": "I'm sorry to hear about your fr...
# ...

# %%
sample_df.to_csv("../final_annotations/sampled_annotations.csv", index=False)
